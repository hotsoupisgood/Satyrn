# %%
print('Hello world')
S0=100.0    # spot stock price
K=100.0     # strike
T=1.0       # maturity 
r=0.1       # risk free rate 
sig=0.2     # diffusion coefficient or volatility
# Out:
# Hello world

# %% [markdown]
# # Hello world
# Are
# $$
# a, b \in \mathbb{R}, then applies (a+b)^{2} = a^{2} + ab + b^{2}
# $$

# %%
rint('hello world21')
# Out:
# ------------------------------------------------------------------
#
# NameError                        Traceback (most recent call last)
#
# <ipython-input-2-b35d3ef0cdeb> in <module>
#
# ----> 1 rint('hello world21')
#
#
#
# NameError: name 'rint' is not defined
