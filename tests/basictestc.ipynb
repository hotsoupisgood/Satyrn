# %%
import matplotlib.pyplot as plt
import random
print(random.random())
# Out:
# before start
# 0.05478910429488826
# after start

# %%
import test_import.test
106%3
# Out:
# before start
# after start

# %%
plt.plot(range(10))
print(random.random())
# Out:
# before start
# 0.418748725463016
# after start

# %%
print(random.random())
# Out:
# before start
# 0.5199653983322483
# after start
